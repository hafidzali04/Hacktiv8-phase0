# %% [markdown]
# #Non Graded Challenge 11
# Assignment Instructions
#
# ---
#
# * Cari Measure of Central Tendency dari data tersebut.
# * Cari Measure of Variance dari data tersebut.
#
#
#
# ---
#
# Assignment Objectives
#
# ---
#
#
# Non-Graded Assignment ini dibuat guna mengevaluasi konsep Descriptive sebagai berikut:
#
# * Memahami konsep Measure of Central Tendency dan implementasinya dengan Python
# * Memahami konsep Measure of Variance dan implementasinya dengan Python

# %%
import pandas as pd
import itertools
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hafidzali04/Hacktiv8-phase0/main/data/covid_19_indonesia_time_series_all.csv')
df.describe()
# Out:
#           New Cases  ...  Growth Factor of New Deaths
# count  21759.000000  ...                 19292.000000
# mean     391.293580  ...                     1.074145
# std     2074.551043  ...                     1.578502
# min        0.000000  ...                     0.000000
# 25%        7.000000  ...                     0.660000
# 50%       41.000000  ...                     1.000000
# 75%      151.000000  ...                     1.000000
# max    56757.000000  ...                   134.500000
#
# [8 rows x 26 columns]

# %%
df.mean()
# Out:
# New Cases                      3.912936e+02
# New Deaths                     1.322041e+01
# New Recovered                  3.773110e+02
# New Active Cases               7.621674e-01
# Total Cases                    8.525997e+04
# Total Deaths                   2.648289e+03
# Total Recovered                7.671260e+04
# Total Active Cases             5.899079e+03
# City or Regency                         NaN
# Total Regencies                2.416026e+01
# Total Cities                   5.872499e+00
# Total Districts                4.204444e+02
# Total Urban Villages           5.087405e+02
# Total Rural Villages           4.490348e+03
# Area (km2)                     1.112418e+05
# Population                     1.547817e+07
# Population Density             7.449898e+02
# Longitude                      1.136808e+02
# Latitude                      -2.731868e+00
# New Cases per Million          2.939303e+01
# Total Cases per Million        6.183651e+03
# New Deaths per Million         8.527267e-01
# Total Deaths per Million       1.635422e+02
# Total Deaths per 100rb         1.635419e+01
# Growth Factor of New Cases     1.395671e+00
# Growth Factor of New Deaths    1.074145e+00
# dtype: float64

# %%
df.median()
# Out:
# New Cases                      4.100000e+01
# New Deaths                     1.000000e+00
# New Recovered                  3.100000e+01
# New Active Cases               0.000000e+00
# Total Cases                    1.078000e+04
# Total Deaths                   2.830000e+02
# Total Recovered                8.745000e+03
# Total Active Cases             9.190000e+02
# City or Regency                         NaN
# Total Regencies                1.100000e+01
# Total Cities                   2.000000e+00
# Total Districts                1.690000e+02
# Total Urban Villages           1.750000e+02
# Total Rural Villages           1.591000e+03
# Area (km2)                     4.201300e+04
# Population                     4.216171e+06
# Population Density             1.038400e+02
# Longitude                      1.134177e+02
# Latitude                      -2.461746e+00
# New Cases per Million          8.160000e+00
# Total Cases per Million        2.727460e+03
# New Deaths per Million         1.800000e-01
# Total Deaths per Million       7.355000e+01
# Total Deaths per 100rb         7.350000e+00
# Growth Factor of New Cases     9.900000e-01
# Growth Factor of New Deaths    1.000000e+00
# dtype: float64

# %%
df.mode()
# Out:
#           Date  ... Growth Factor of New Deaths
# 0     1/1/2021  ...                         1.0
# 1    1/10/2021  ...                         NaN
# 2    1/11/2021  ...                         NaN
# 3    1/12/2021  ...                         NaN
# 4    1/13/2021  ...                         NaN
# ..         ...  ...                         ...
# 586   9/7/2021  ...                         NaN
# 587   9/8/2020  ...                         NaN
# 588   9/8/2021  ...                         NaN
# 589   9/9/2020  ...                         NaN
# 590   9/9/2021  ...                         NaN
#
# [591 rows x 38 columns]

# %%
#Range
rangecol = ["New Cases", "New Deaths", "New Recovered", "New Active Cases"]
for col in rangecol:
    print(df[col].name + " Range " + str(df[col].max() - df[col].min()))
# Out:
# New Cases Range 56757
# New Deaths Range 2069
# New Recovered Range 48832
# New Active Cases Range 62451

# %%
#Pencentiles
print(stats.percentileofscore(df['Total Regencies'], 8, 'strict'))
print(stats.percentileofscore(df['Total Regencies'], 8, 'weak'))
print(stats.percentileofscore(df['Total Regencies'], 8, 'rank'))
# Out:
# 25.6905188657567
# 34.23870582287789
# 29.96691024403695

# %%
#Quartiles
print(df['Total Regencies'].quantile([0.25, 0.5, 0.75]))
# Out:
# 0.25     7.0
# 0.50    11.0
# 0.75    18.0
# Name: Total Regencies, dtype: float64

# %%
#Outliers
df['Total Regencies'].plot(kind='box', title='', figsize=(10,8), showfliers=False)
plt.show()

# %%
#Variance
print(df['Total Regencies'].var())
# Out:
# 4720.825727961557

# %%
#Standart Deviation
print(df['Total Regencies'].std())
# Out:
# 68.7082653540428

# %%
#Z Score
Zscore =(df['Total Regencies'] - df['Total Regencies'].mean()) / df['Total Regencies'].std()
Zscore
# Out:
# 0       -0.337081
# 1       -0.337081
# 2        5.702949
# 3       -0.206092
# 4       -0.337081
#            ...
# 21754   -0.191538
# 21755   -0.176984
# 21756   -0.162430
# 21757    0.012222
# 21758    5.702949
# Name: Total Regencies, Length: 21759, dtype: float64

# %%
mines = []
maka = []
for zero in Zscore:
    if zero > 0:
        maka.append(zero)
    elif zero < 0:
        mines.append(zero)
print("Total yang lebih dari mean: " + str(len(maka)))  
print("Total yang tidak lebih dari mean: " + str(len(mines)))
# Out:
# Total yang lebih dari mean: 3149
# Total yang tidak lebih dari mean: 18610
